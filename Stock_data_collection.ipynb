# %%
import requests
import pprint
import pandas as pd

# %%
# Function to fetch stock data from Alpha Vantage
def fetch_stock_data(symbol):
    api_key = '8VIUS7A7H07O4J4T'  # Replace with your Alpha Vantage API key
    base_url = 'https://www.alphavantage.co/query'

    # Make an API request to retrieve stock data
    params = {
        'function': 'OVERVIEW',
        'symbol': symbol,
        'apikey': api_key
    }
    response = requests.get(base_url, params=params)
    data = response.json()

    return data

# %%
# Fetch stock data for each stock and store in a list
def get_stock_data_dict_list(stocks):
    stock_data_list = []
    for stock in stocks:
        stock_data = fetch_stock_data(stock)
        stock_data_list.append(stock_data)
    return stock_data_list

# %%
# Choose ten stocks randomly (example list)
stocks = ['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'FB', 'TSLA', 'JPM', 'V', 'NVDA', 'MA']

# %%
stock_data_list = get_stock_data_dict_list(stocks)
df_stock_data_list = pd.DataFrame(stock_data_list)
df_stock_data_list = df_stock_data_list.dropna(subset=['Symbol'])

# %%
df_stock_data_list.head(10)
# Out:
#   Symbol     AssetType                   Name  \
# 0   AAPL  Common Stock              Apple Inc
# 1  GOOGL  Common Stock   Alphabet Inc Class A
# 2   MSFT  Common Stock  Microsoft Corporation
# 3   AMZN  Common Stock         Amazon.com Inc
# 5   TSLA  Common Stock              Tesla Inc
# 6    JPM  Common Stock    JPMorgan Chase & Co
# 7      V  Common Stock      Visa Inc. Class A
#
#                                          Description      CIK Exchange  \
# 0  Apple Inc. is an American multinational techno...   320193   NASDAQ
# 1  Alphabet Inc. is an American multinational con...  1652044   NASDAQ
# 2  Microsoft Corporation is an American multinati...   789019   NASDAQ
# 3  Amazon.com, Inc. is an American multinational ...  1018724   NASDAQ
# 5  Tesla, Inc. is an American electric vehicle an...  1318605   NASDAQ
# 6  JPMorgan Chase & Co. is an American multinatio...    19617     NYSE
# 7  Visa Inc. is an American multinational financi...  1403161     NYSE
#
# ...
